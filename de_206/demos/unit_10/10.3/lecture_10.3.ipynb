# %%
# Import the Fourier series demonstration module
import demo as fsd

# %% [markdown]
# # Fourier Series Convergence Explorer
#
# This interactive demonstration allows you to:
# - Explore how Fourier series approximate different periodic functions
# - Visualize the Gibbs phenomenon at discontinuities
# - Analyze convergence rates for different function types
#
# ## Instructions:
# 1. Select a function type from the dropdown
# 2. Adjust the number of terms using the slider
# 4. Observe the error metrics shown below the plots

# %%
fsd.run_demo()

# %%
fsd.plot_error_vs_n(200)
